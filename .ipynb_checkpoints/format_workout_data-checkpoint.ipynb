# %%
#basic imports
import numpy as np
import pandas as pd

import glob
import json
from datetime import date

# %% [markdown]
# Todo
# - Add in fitbit sleep analysis and heartrate scores
# - Total time resting vs. total time working out
# - % of time in heart rate zones
# - Number of steps, distance, calories, elevation, floors
# - time slept previous day
# - time slept the day of the workout
# - time slept the next day
# - general sleep metrics
# - Duration of workout
# - Start time of workout
# - End time of workout
# - Columnar intraday data for heart rate over time

# %%
def format_columns(df):
    '''set columns to lowercase, strip, and replace spaces with underscores'''
    df.columns = (df.columns
                  .str.strip()
                  .str.lower()
                  .str.replace(' \(lbs\)', '')
                  .str.replace(' ', '_') #remove the (lbs) subtitle on from weight
                 )
    return df

def impute_workout_features(df, routines):
    '''impute workout features'''
    #merging together some musclegroup categories
    condensed_categories = {
        'Triceps': 'Chest',
        'Biceps': 'Back'
    }
    df['category'] = df.category.replace(condensed_categories)
    
    #set up datetime index
    df['date'] = pd.to_datetime(df.date)
    
    #calculate total volume
    df['volume'] = df.eval('weight * reps')
    #determine Epley-formulated 1-rep max based
    df['one_rep_max'] = df.eval('weight + weight * reps / 30')
    
    #calculate speed for cardio
    df['time'] = pd.to_datetime(df.time)
    df['time'] = df.time.dt.minute * 60 + df.time.dt.second
    df['speed'] = df.eval('distance / time')
    
    #impute workout day by the max number of lifts in a category
    df['workout_day'] = df.groupby('date').category.transform(lambda s: s.value_counts(ascending = False).index[0])
    
    #determine completed sets
    df['set_completed'] = np.where(df.weight > 0, 1, 0)

    #Assign the routine each workout belongs to
    #iterate through routines database
    for row in routines.itertuples():
        #determine whether the dates of a workout category from fitnotes are within that categories start
        #and end dates from the routines database
        is_between_dates = df[df.category == row.category].date.between(row.start_date, row.end_date)
        #if true, assign the corresponding routine; else, NaN
        df.loc[df.category == row.category, 'routine'] = np.where(is_between_dates, row.routine, np.NaN)
    #replacing string nans with numpy nans, which propagate from np where for some reason, return to fix
    df.routine = df.routine.replace('nan', np.NaN)
    
    #set index as date for resampling later
    df = df.set_index('date')

    return df

def calculate_age(date):
    '''Calculate how old I am on a particular date'''
    #source: https://stackoverflow.com/questions/2217488/age-from-birthdate-in-python/2259711
    #My age is today's year minus the year of my birth.
    return date.year - born.year - ((date.month, date.day) < (born.month, born.day))

def compute_gains_matrix(df):
    '''Create matrix of aggregated key performance indicators for workouts'''
    #remove cardio workouts
    df = df.loc[df.category != 'Cardio']
    #filling nans so the max aggfunc can work on the routine
    df.routine = df.routine.replace(np.NaN, 'n/a')
    #get key performance indicators for the workout
    gains = df.pivot_table(index = 'date', 
                           values = ['volume', 'reps', 'weight', 'workout_day', 'set_completed', 'one_rep_max', 'routine'],
                           aggfunc = {'volume': 'sum', 
                                            'reps': 'mean', 
                                            'weight': 'max', 
                                            'one_rep_max': 'max',
                                            'workout_day': 'max',
                                            'set_completed': 'mean',
                                            'routine': 'max'})

    #renaming the set completed to completion rate because all sets comprise a workout
    gains = gains.rename(columns = {'set_completed': 'completion_rate',
                                    'reps': 'mean_reps', 
                                    'weight': 'max_weight',
                                    'volume': 'total_volume'})
    workout_dates = df.index.unique()
    gains['primary_lift'] = df.groupby('date').apply(lambda g: g.set_index('exercise').weight.idxmax())
    gains['days_since_last_workout'] = gains.reset_index().date.diff().fillna(0).values
    
    gains = gains.reset_index().sort_values(['workout_day', 'date'])
    gains['days_since_last_workout_day'] = gains.groupby('workout_day').apply(lambda g: g.reset_index().date.diff().fillna(0)).values
    gains['weekday'] = gains.date.dt.weekday_name
    #calculate my age
    born = date(1995, 1, 1)
    gains['age'] = gains['date'].dt.date.apply(calculate_age)
    #as of merge to get last known weight and then interpolate
    gains = gains.sort_values('date')
    gains = pd.merge_asof(gains, weight[['date', 'weight']], on = 'date')
    gains['weight'] = gains.weight.interpolate()
    gains.rename(columns = {'weight': 'bodyweight'}, inplace = True)
    return gains

# %%
saved_workouts = glob.glob('fitnotes/Fitnotes*.csv')
fitnotes = pd.read_csv(saved_workouts[-1]).pipe(format_columns)
routines = pd.read_csv('routines.csv', 
                         parse_dates = ['Start Date', 'End Date']).pipe(format_columns)

weight = pd.read_csv('fitbit/weight.csv', parse_dates = ['date'])
lifts = impute_workout_features(fitnotes, routines)
lifts.to_csv('lifts.csv')

gains = compute_gains_matrix(lifts)
gains.to_csv('gains.csv')
# Out:
# C:\Users\William Greenlaw\Anaconda3\lib\site-packages\pandas\core\generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
gains
# Out:
#           date  one_rep_max  mean_reps                     routine  \
# 0   2014-06-07   200.000000   8.222222                         n/a
# 1   2014-06-08    73.333333  10.000000                         n/a
# 2   2014-06-10   300.000000  10.000000                         n/a
# 3   2014-06-17    73.333333   8.200000                         n/a
# 4   2014-06-19   320.000000   8.153846                         n/a
# 5   2014-06-22   340.000000   8.500000                         n/a
# 6   2014-06-24   200.000000   7.615385                         n/a
# 7   2014-07-01    80.000000   9.000000                         n/a
# 8   2014-07-02   206.666667   7.166667                         n/a
# 9   2014-07-07    86.666667   8.166667                         n/a
# 10  2014-07-09   152.000000   7.666667                         n/a
# 11  2014-07-13    66.666667  10.000000                         n/a
# 12  2014-07-16    86.666667  10.000000                         n/a
# 13  2014-07-22   340.000000   8.500000                         n/a
# 14  2014-07-23   200.000000  10.000000                         n/a
# 15  2014-07-27   213.333333   7.083333                         n/a
# 16  2014-07-30   200.000000  10.000000                         n/a
# 17  2014-08-07     1.200000   4.666667                         n/a
# 18  2014-08-08   220.000000   4.333333                         n/a
# 19  2014-08-14    86.666667   7.833333                         n/a
# 20  2014-08-15    46.666667   6.800000                         n/a
# 21  2014-08-17   120.000000  13.066667                         n/a
# 22  2014-08-18   142.500000  12.933333                         n/a
# 23  2014-09-03   120.000000  13.066667                         n/a
# 24  2014-09-06   142.500000  12.933333                         n/a
# 25  2014-10-17   172.500000  13.333333                         n/a
# 26  2014-10-18   120.000000  14.000000                         n/a
# 27  2014-11-30   221.666667   7.307692                         n/a
# 28  2014-12-18    66.666667   9.400000                         n/a
# 29  2014-12-19   133.333333  10.000000                         n/a
# ..         ...          ...        ...                         ...
# 342 2018-09-19   100.000000  10.000000  Princess Diana Gains Guide
# 343 2018-09-21     1.400000  18.400000  Princess Diana Gains Guide
# 344 2018-10-01   180.000000   9.600000  Princess Diana Gains Guide
# 343         0.133333          24.0         1.0         Abs
# 344         0.600000        8690.0       135.0       Chest
# 345         0.333333          60.0         1.0         Abs
# 346         1.000000        2356.0        75.0        Back
# 347         0.333333          60.0         1.0         Abs
# 348         0.954545        9086.0       135.0       Chest
# 349         1.000000        1708.0        80.0        Back
# 350         0.920000       12020.0       140.0       Chest
# 351         0.333333          60.0         1.0         Abs
# 352         1.000000          32.0         1.0        Back
# 353         1.000000         195.0         1.0         Abs
# 354         0.360000        6070.0       145.0       Chest
# 355         0.400000          84.0         1.0         Abs
# 356         1.000000         992.0        80.0        Back
# 357         1.000000       13289.0       145.0       Chest
# 358         1.000000        1982.0        80.0        Back
# 359         1.000000         225.0         1.0         Abs
# 360         0.480000        6734.0       150.0       Chest
# 361         1.000000         834.0        80.0        Back
# 362         1.000000         240.0         1.0         Abs
# 363         0.884615       11003.0       155.0       Chest
# 364         1.000000        2230.0        80.0        Back
# 365         1.000000         255.0         1.0         Abs
# 366         0.695652        9835.0       160.0       Chest
# 367         1.000000        2211.0        80.0        Back
# 368         0.200000          54.0         1.0         Abs
# 369         1.000000        9600.0       165.0       Chest
# 370         0.533333         128.0         1.0         Abs
# 371         1.000000       13089.0       170.0       Chest
#
#                             primary_lift days_since_last_workout  \
# 0                           Lat Pulldown                  0 days
# 1              Flat Dumbbell Bench Press                  1 days
# 2                              Leg Press                  2 days
# 3              Flat Dumbbell Bench Press                  7 days
# 4                              Leg Press                  2 days
# 5                              Leg Press                  3 days
# 6                           Lat Pulldown                  2 days
# 7              Flat Dumbbell Bench Press                  7 days
# 8                           Lat Pulldown                  1 days
# 9              Flat Dumbbell Bench Press                  5 days
# 10                      Seated Cable Row                  2 days
# 11   Dumbbell Overhead Triceps Extension                  4 days
# 12             Flat Dumbbell Bench Press                  3 days
# 13                             Leg Press                  6 days
# 14                          Lat Pulldown                  1 days
# 15                    Seated Machine Fly                  4 days
# 16                          Lat Pulldown                  3 days
# 17                               Pull Up                  8 days
# 18                    Seated Machine Fly                  1 days
# 19                          Dumbbell Row                  6 days
# 20               Dumbbell Shoulder Press                  1 days
# 21             Flat Dumbbell Bench Press                  2 days
# 22                         Bent Over Row                  1 days
# 23             Flat Dumbbell Bench Press                 16 days
# 24                         Bent Over Row                  3 days
# 25                          Lat Pulldown                 41 days
# 26              Flat Barbell Bench Press                  1 days
# 27              Flat Barbell Bench Press                 43 days
# 28             Flat Dumbbell Bench Press                 18 days
# 29                   Dumbbell Calf Raise                  1 days
# ..                                   ...                     ...
# 342          Decline Dumbbell Benchpress                  1 days
# 343                Decline Oblique Chops                  2 days
# 344          Decline Barbell Bench Press                 10 days
# 345                Decline Oblique Chops                  2 days
# 346                         Dumbbell Row                  1 days
# 347                Decline Oblique Chops                  5 days
# 348          Decline Barbell Bench Press                  1 days
# 349                         Dumbbell Row                  2 days
# 350          Decline Barbell Bench Press                 11 days
# 351                Decline Oblique Chops                  1 days
# 352                              Pull Up                  1 days
# 353                Decline Oblique Chops                  2 days
# 354          Decline Barbell Bench Press                  6 days
# 355                Decline Oblique Chops                  3 days
# 356                         Dumbbell Row                  1 days
# 357          Decline Barbell Bench Press                  6 days
# 358                         Dumbbell Row                  4 days
# 359                Decline Oblique Chops                  8 days
# 360          Decline Barbell Bench Press                  2 days
# 361                         Dumbbell Row                  4 days
# 362                Decline Oblique Chops                  1 days
# 363          Decline Barbell Bench Press                  2 days
# 364                         Dumbbell Row                  2 days
# 365                Decline Oblique Chops                  3 days
# 366          Decline Barbell Bench Press                  2 days
# 367                         Dumbbell Row                  4 days
# 368                Decline Oblique Chops                  1 days
# 369          Decline Barbell Bench Press                 11 days
# 370                Decline Oblique Chops                  3 days
# 371          Decline Barbell Bench Press                  4 days
#
#     days_since_last_workout_day    weekday  age  bodyweight
# 0                        0 days   Saturday   19         NaN
# 1                        0 days     Sunday   19         NaN
# 2                        0 days    Tuesday   19         NaN
# 3                        9 days    Tuesday   19         NaN
# 4                        9 days   Thursday   19         NaN
# 5                        3 days     Sunday   19         NaN
# 6                       17 days    Tuesday   19         NaN
# 7                       14 days    Tuesday   19         NaN
# 8                        8 days  Wednesday   19         NaN
# 9                        6 days     Monday   19         NaN
# 10                       7 days  Wednesday   19         NaN
# 11                       6 days     Sunday   19         NaN
# 12                       3 days  Wednesday   19         NaN
# 13                      30 days    Tuesday   19         NaN
# 14                      14 days  Wednesday   19         NaN
# 15                      11 days     Sunday   19         NaN
# 16                       7 days  Wednesday   19         NaN
# 17                       8 days   Thursday   19         NaN
# 18                      12 days     Friday   19         NaN
# 19                       7 days   Thursday   19         NaN
# 20                       0 days     Friday   19         NaN
# 21                       9 days     Sunday   19         NaN
# 22                       4 days     Monday   19         NaN
# 23                      17 days  Wednesday   19         NaN
# 24                      19 days   Saturday   19         NaN
# 25                      41 days     Friday   19         NaN
# 26                      45 days   Saturday   19         NaN
# 27                      43 days     Sunday   19         NaN
# 28                      18 days   Thursday   19         NaN
# 29                     150 days     Friday   19         NaN
# ..                          ...        ...  ...         ...
# 342                      7 days  Wednesday   23       190.5
# 343                      3 days     Friday   23       190.5
# 344                     12 days     Monday   23       187.5
# 345                     12 days  Wednesday   23       187.5
# 346                     17 days   Thursday   23       187.5
# 347                      6 days    Tuesday   23       190.5
# 348                      9 days  Wednesday   23       190.5
# 349                      8 days     Friday   23       190.5
# 350                     13 days    Tuesday   23       190.5
# 351                     15 days  Wednesday   23       190.5
# 352                     13 days   Thursday   23       190.5
# 353                      3 days   Saturday   23       189.0
# 354                     10 days     Friday   23       189.0
# 355                      9 days     Monday   23       190.0
# 356                     12 days    Tuesday   23       190.0
# 357                     10 days     Monday   23       188.5
# 358                     10 days     Friday   23       188.5
# 359                     19 days   Saturday   23       188.5
# 360                     14 days     Monday   23       188.5
# 361                     14 days     Friday   23       188.5
# 362                      7 days   Saturday   23       189.5
# 363                      7 days     Monday   23       189.5
# 364                      5 days  Wednesday   23       189.5
# 365                      7 days   Saturday   23       189.5
# 366                      7 days     Monday   23       189.5
# 367                      9 days     Friday   23       189.5
# 368                      7 days   Saturday   23       192.0
# 369                     16 days  Wednesday   23       194.0
# 370                     14 days   Saturday   23       194.0
# 371                      7 days  Wednesday   24       194.0
#
# [372 rows x 14 columns]
